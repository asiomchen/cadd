# %%
import pandas as pd
import numpy as np
import sys,os
sys.path.insert(0,'../')
from utils.extract_scores import Extractor

# %%
base_name = '../results/qvina-best-pocket/docked_pocket_'
temp_df = None
all_results = None
for e in [16,32,64]:
    res_dir = base_name + str(e)
    temp_df = Extractor(data_path=res_dir).extract()
    temp_df['e'] = e
    temp_df.reset_index(inplace=True)
    if all_results is None:
        all_results = temp_df.copy()
    else:
       all_results = pd.concat([all_results, temp_df], axis=0)
    print(temp_df.head())
# Out:
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_16/1_1_2965.pdbqt)
#
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
#    index      name  pose  score  \
# 0      0  1_1_2381   0.0  -13.0
# 1      1  1_1_2381   1.0  -12.4
# 2      2  1_1_2381   2.0  -12.1
# 3      3  1_1_2381   3.0  -12.1
# 4      4  1_1_2381   4.0  -12.0
#
#                                             centroid  \
# 0  Point(37.860491017964065, 26.84025748502995, 2...
# 1  Point(38.34494011976049, 26.846532934131737, 2...
# 2  Point(41.84386826347305, 25.309538922155696, 3...
# 3  Point(39.52835928143713, 30.022311377245487, 2...
# 4  Point(37.725628742514985, 27.81560479041917, 2...
#
#                                               coords   e
# 0  [[33.494, 26.759, 24.796], [34.113, 25.84, 24....  16
# 1  [[33.996, 28.656, 24.791], [34.613, 28.669, 23...  16
# 2  [[43.34, 22.466, 28.075], [43.372, 22.577, 29....  16
# 3  [[37.14, 32.721, 30.591], [37.544, 33.883, 30....  16
# 4  [[33.683, 28.98, 25.101], [34.685, 28.679, 24....  16
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_32/1_1_2965.pdbqt)
#
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
#    index      name  pose  score  \
# 0      0  1_1_2381   0.0  -12.4
# 1      1  1_1_2381   1.0  -11.6
# 2      2  1_1_2381   2.0  -11.4
# 3      3  1_1_2381   3.0  -11.4
# 4      4  1_1_2381   4.0  -11.4
#
#                                             centroid  \
# 0  Point(39.55046107784432, 28.959616766467086, 2...
# 1  Point(40.42869461077845, 28.488167664670648, 2...
# 2  Point(41.05232934131738, 28.250982035928132, 2...
# 3  Point(40.59665868263473, 28.40585029940119, 27...
# 4  Point(40.76231137724553, 28.159646706586837, 2...
#
#                                               coords   e
# 0  [[33.599, 28.255, 24.158], [34.072, 28.242, 23...  32
# 1  [[42.016, 21.917, 27.934], [42.286, 22.397, 29...  32
# 2  [[43.138, 23.27, 25.228], [43.058, 22.192, 24....  32
# 3  [[41.973, 21.981, 27.831], [42.118, 22.387, 28...  32
# 4  [[41.41, 22.6, 27.561], [41.499, 22.6, 28.795]...  32
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ../results/qvina-best-pocket/docked_pocket_64/1_1_2965.pdbqt)
#
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# 10 molecules converted
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
# Number of molecules in xyz file: 10
#    index      name  pose  score  \
# 0      0  1_1_2381   0.0  -12.4
# 1      1  1_1_2381   1.0  -12.1
# 2      2  1_1_2381   2.0  -11.9
# 3      3  1_1_2381   3.0  -11.6
# 4      4  1_1_2381   4.0  -11.5
#
#                                             centroid  \
# 0  Point(39.55046107784432, 28.959616766467086, 2...
# 1  Point(40.53048502994014, 28.268125748502996, 2...
# 2  Point(39.64248502994014, 28.57433532934131, 28...
# 3  Point(42.97711377245509, 24.810904191616757, 2...
# 4  Point(40.24589820359282, 28.5793892215569, 28....
#
#                                               coords   e
# 0  [[33.599, 28.255, 24.158], [34.072, 28.242, 23...  64
# 1  [[37.126, 33.27, 31.346], [36.76, 34.074, 32.2...  64
# 2  [[33.932, 32.644, 28.341], [33.032, 33.132, 27...  64
# 3  [[42.852, 22.695, 27.773], [42.688, 22.853, 28...  64
# 4  [[37.525, 30.374, 28.438], [38.119, 29.679, 27...  64

# %%
all_results.head()
# Out:
#    index      name  pose  score  \
# 0      0  1_1_2381   0.0  -13.0
# 1      1  1_1_2381   1.0  -12.4
# 2      2  1_1_2381   2.0  -12.1
# 3      3  1_1_2381   3.0  -12.1
# 4      4  1_1_2381   4.0  -12.0
#
#                                             centroid  \
# 0  Point(37.860491017964065, 26.84025748502995, 2...
# 1  Point(38.34494011976049, 26.846532934131737, 2...
# 2  Point(41.84386826347305, 25.309538922155696, 3...
# 3  Point(39.52835928143713, 30.022311377245487, 2...
# 4  Point(37.725628742514985, 27.81560479041917, 2...
#
#                                               coords   e
# 0  [[33.494, 26.759, 24.796], [34.113, 25.84, 24....  16
# 1  [[33.996, 28.656, 24.791], [34.613, 28.669, 23...  16
# 2  [[43.34, 22.466, 28.075], [43.372, 22.577, 29....  16
# 3  [[37.14, 32.721, 30.591], [37.544, 33.883, 30....  16
# 4  [[33.683, 28.98, 25.101], [34.685, 28.679, 24....  16

# %%
all_results.head()
# Out:
#    index      name  pose  score  \
# 0      0  1_1_2381   0.0  -13.0
# 1      1  1_1_2381   1.0  -12.4
# 2      2  1_1_2381   2.0  -12.1
# 3      3  1_1_2381   3.0  -12.1
# 4      4  1_1_2381   4.0  -12.0
#
#                                             centroid  \
# 0  Point(37.860491017964065, 26.84025748502995, 2...
# 1  Point(38.34494011976049, 26.846532934131737, 2...
# 2  Point(41.84386826347305, 25.309538922155696, 3...
# 3  Point(39.52835928143713, 30.022311377245487, 2...
# 4  Point(37.725628742514985, 27.81560479041917, 2...
#
#                                               coords   e
# 0  [[33.494, 26.759, 24.796], [34.113, 25.84, 24....  16
# 1  [[33.996, 28.656, 24.791], [34.613, 28.669, 23...  16
# 2  [[43.34, 22.466, 28.075], [43.372, 22.577, 29....  16
# 3  [[37.14, 32.721, 30.591], [37.544, 33.883, 30....  16
# 4  [[33.683, 28.98, 25.101], [34.685, 28.679, 24....  16

# %%
len(all_results)
# Out:
# 2880

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("white")

# %%
sns.violinplot(data=all_results,x='e', y='score')
plt.xlabel('exhaustiveness')
plt.ylabel('score [kcal]')
plt.title('Docking performance')
# Out:
# Text(0.5, 1.0, 'Docking performance')

# %%
sns.violinplot(data=all_results[all_results.pose == 0],x='e', y='score')
plt.xlabel('exhaustiveness')
plt.ylabel('score [kcal]')
# Out:
# Text(0, 0.5, 'score [kcal]')

# %%
all_results.groupby('e')['score'].mean()
# Out:
# e
# 16   -11.403125
# 32   -11.592083
# 64   -11.730625
# Name: score, dtype: float64

# %%
all_results.groupby('e')['score'].median()
# Out:
# e
# 16   -11.7
# 32   -11.8
# 64   -11.9
# Name: score, dtype: float64

# %%
all_results['centroid_x'] = all_results['centroid'].apply(lambda x: x.x)
all_results['centroid_y'] = all_results['centroid'].apply(lambda x: x.y)
all_results['centroid_z'] = all_results['centroid'].apply(lambda x: x.z)

# %%
def plot_points(df, legend=False):
    """
    Plots clusters made from vectorized procedure in 3D
    param:matrix - np.ndarray of vectors to plot
    param:model - sklearn model to predict labels
    return: pd.Dataframe
    """
    sns.set_style("white")

    x_axis = [o for o in df['centroid_x']]
    y_axis = [o for o in df['centroid_y']]
    z_axis = [o for o in df['centroid_z']]
    df_dict = {'id':df.name, 'x': x_axis, 'y': y_axis, 'z':z_axis}
    df_plot = pd.DataFrame(df_dict)

    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111, projection='3d')
    for i in df_plot.id.unique():
        i_cluster = df_plot[df_plot.id == i]
        x = i_cluster['x']
        y = i_cluster['y']
        z = i_cluster['z']
        ax.scatter3D(x,y,z, s=40, label=i, alpha=1)
    if legend:
        ax.legend()
    plt.show()

    return df_plot

# %%
to_cluster = plot_points(all_results).drop('id', axis=1)

# %%
from sklearn.cluster import KMeans

# %%
len(to_cluster)
# Out:
# 2880

# %%
inertias = []
n_clusters = []
for n in range(1, 10, 1):
    model = KMeans(n_clusters=n)
    model.fit(to_cluster)
    inertias.append(model.inertia_)
    n_clusters.append(n)
sns.lineplot(x=n_clusters, y=inertias)
# Out:
# <AxesSubplot: >

# %%
def elbow_plot(method=None, data=None, lims=(5,15)):
    inertias = []
    n_clusters = []
    for n in range(lims[0], lims[1] + 1):
        model = method(n_clusters=n)
        model.fit(data)
        inertias.append(model.inertia_)
        n_clusters.append(n)
    sns.set_style("white")
    sns.lineplot(x=n_clusters, y=inertias)
    plt.title('Elbow plot')
    plt.ylabel('Inertia')
    plt.xlabel('Number of clusters')
    plt.xlim(lims[0], lims[1])

# %%
elbow_plot(KMeans, to_cluster, (1,10))

# %%
model_1 = KMeans(n_clusters=3)
model_1.fit(to_cluster)
labels = model_1.labels_

# %%
to_cluster.head()
# Out:
#            x          y          z
# 0  37.860491  26.840257  28.370784
# 1  38.344940  26.846533  28.857970
# 2  41.843868  25.309539  30.552832
# 3  39.528359  30.022311  28.704599
# 4  37.725629  27.815605  29.074371

# %%
sns.scatterplot(data=to_cluster, x='x',y='y', hue=labels, palette=sns.color_palette("Set1", 3))
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %%
all_results['labels'] = labels

# %%
len(set(labels))
# Out:
# 3

# %%
sns.palplot(sns.color_palette("Set1", 10))

# %%
def plot_clusters(df, cluster='labels', alpha=0.5):
    """
    Plots clusters made from vectorized procedure in 3D
    param:matrix - np.ndarray of vectors to plot
    param:model - sklearn model to predict labels
    return: pd.Dataframe
    """
    # color_labels = df[hue].unique()
    # rgb_values = sns.color_palette("Set2", len(color_labels))
    # color_map = dict(zip(color_labels, rgb_values))

    x_axis = [o for o in df['centroid_x']]
    y_axis = [o for o in df['centroid_y']]
    z_axis = [o for o in df['centroid_z']]


    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111, projection='3d')
    for i in df[cluster].unique():
        i_cluster = df[df[cluster] == i]
        x = i_cluster['centroid_x']
        y = i_cluster['centroid_y']
        z = i_cluster['centroid_z']
        ax.scatter3D(x,y,z, s=40, label=i, alpha=alpha)
    ax.legend()
    plt.show()

# %%
plot_clusters(all_results, alpha=0.1)

# %%
all_results.groupby('labels')['score'].describe()
# Out:
#          count       mean       std   min     25%   50%   75%  max
# labels
# 0        492.0 -10.731301  1.360512 -13.4 -11.725 -11.1 -10.0 -5.9
# 1       1092.0 -11.681960  0.929058 -13.9 -12.200 -11.9 -11.3 -7.6
# 2       1296.0 -11.805787  0.903766 -13.8 -12.300 -11.9 -11.5 -6.2

# %%
high = all_results[all_results.score < -12]

# %%
high.groupby('labels')['score'].count()
# Out:
# labels
# 0     65
# 1    406
# 2    544
# Name: score, dtype: int64

# %%
from sklearn.decomposition import PCA

coords = to_cluster[['x','y', 'z']]
pca = PCA(n_components=2)
coords
# Out:
#              x          y          z
# 0    37.860491  26.840257  28.370784
# 1    38.344940  26.846533  28.857970
# 2    41.843868  25.309539  30.552832
# 3    39.528359  30.022311  28.704599
# 4    37.725629  27.815605  29.074371
# ..         ...        ...        ...
# 955  37.543876  27.822814  28.309898
# 956  39.306407  28.872130  27.413017
# 957  39.406960  29.261859  27.765582
# 958  36.449927  28.417051  29.526814
# 959  40.717960  26.957605  26.799938
#
# [2880 rows x 3 columns]

# %%
coords = pca.fit_transform(coords)
plt.scatter(coords[:,0], coords[:,1], alpha=0.5)
plt.show()

# %%
elbow_plot(KMeans, coords, (1,10))

# %%
model_2 = KMeans(n_clusters=3).fit(coords)
pca_labels = model_2.labels_

# %%
sns.scatterplot(x=coords[:,0], y=coords[:,1], alpha=0.5, hue=pca_labels, palette=sns.color_palette())
plt.show()
# Out:
# /tmp/ipykernel_37759/742188949.py:1: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.scatterplot(x=coords[:,0], y=coords[:,1], alpha=0.5, hue=pca_labels, palette=sns.color_palette())

# %%
all_results['pocket'] = pca_labels

# %%
sns.scatterplot(x=coords[:,0], y=coords[:,1], hue=pca_labels, palette=sns.color_palette(), alpha=0.3)
energies = all_results.groupby('pocket')['score'].mean().values
energies_median = all_results.groupby('pocket')['score'].median().values
for centroid, energy, median in zip(model_2.cluster_centers_, energies, energies_median):
    energy_str = 'Mean: ' + str(energy)[:6]
    energy_median = str(median)[:6]
    x = centroid[0]
    y = centroid[1]
    #plt.text(x + 0.5, y, energy_str, horizontalalignment='left', size='medium', color='black', weight='semibold')
    plt.text(x, y, energy_median, horizontalalignment='left', size='large', color='black', weight='bold')
# Out:
# /tmp/ipykernel_37759/433300895.py:1: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.scatterplot(x=coords[:,0], y=coords[:,1], hue=pca_labels, palette=sns.color_palette(), alpha=0.3)

# %%
all_results[all_results.pocket ==1].sort_values('score').head()
# Out:
#      index      name  pose  score  \
# 541      1  1_1_1585   1.0  -13.4
# 542      2  1_1_1585   2.0  -13.3
# 546      6  1_1_1585   6.0  -13.2
# 540      0  1_1_1585   0.0  -13.1
# 549      9  1_1_1585   9.0  -13.0
#
#                                               centroid  \
# 541  Point(40.5310909090909, 28.78073426573429, 30....
# 542  Point(41.233531468531474, 31.64790909090909, 3...
# 546  Point(43.78630069930071, 27.082720279720284, 3...
# 540  Point(40.39592307692307, 30.111321678321666, 2...
# 549  Point(41.187174825174836, 28.90413286713288, 2...
#
#                                                 coords   e  centroid_x  \
# 541  [[40.481, 33.888, 36.513], [41.425, 34.244, 36...  64   40.531091
# 542  [[36.144, 33.6, 34.714], [35.197, 33.992, 35.0...  64   41.233531
# 546  [[46.935, 24.479, 25.102], [47.984, 24.415, 25...  64   43.786301
# 540  [[45.892, 31.407, 26.734], [46.794, 31.642, 26...  32   40.395923
# 549  [[45.502, 28.329, 28.453], [44.851, 28.785, 27...  64   41.187175
#
#      centroid_y  centroid_z  labels  pocket
# 541   28.780734   30.501860       0       1
# 542   31.647909   30.150825       0       1
# 546   27.082720   30.143832       0       1
# 540   30.111322   29.268832       0       1
# 549   28.904133   29.660951       0       1

# %%
plot_clusters(all_results, cluster='pocket', alpha=0.3)

# %%
sns.scatterplot(x=all_results.centroid_x, y=all_results.centroid_y, hue=all_results.labels, palette=sns.color_palette(), alpha=0.3)
plt.title('Clustered centroids - mean')
energies = all_results.groupby('labels')['score'].mean().values
energies_median = all_results.groupby('labels')['score'].median().values
for centroid, energy, median in zip(model_1.cluster_centers_, energies, energies_median):
    energy_str = str(energy)[:6]
    energy_median = str(median)[:6]
    x = centroid[0]
    y = centroid[1]
    #plt.text(x + 0.5, y, energy_str, horizontalalignment='left', size='medium', color='black', weight='semibold')
    plt.text(x, y, energy_str, horizontalalignment='left', size='large', color='black', weight='bold')
# Out:
# /tmp/ipykernel_37759/1045697033.py:1: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.scatterplot(x=all_results.centroid_x, y=all_results.centroid_y, hue=all_results.labels, palette=sns.color_palette(), alpha=0.3)

# %%
sns.scatterplot(x=all_results.centroid_x, y=all_results.centroid_y, hue=all_results.labels, palette=sns.color_palette(), alpha=0.3)
plt.title('Clustered centroids - median')
energies = all_results.groupby('labels')['score'].mean().values
energies_median = all_results.groupby('labels')['score'].median().values
for centroid, energy, median in zip(model_1.cluster_centers_, energies, energies_median):
    energy_str = str(energy)[:6]
    energy_median = str(median)[:6]
    x = centroid[0]
    y = centroid[1]
    #plt.text(x + 0.5, y, energy_str, horizontalalignment='left', size='medium', color='black', weight='semibold')
    plt.text(x, y, energy_median, horizontalalignment='left', size='large', color='black', weight='bold')
# Out:
# /tmp/ipykernel_37759/400248908.py:1: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.scatterplot(x=all_results.centroid_x, y=all_results.centroid_y, hue=all_results.labels, palette=sns.color_palette(), alpha=0.3)

# %%
coords = to_cluster[['x','y', 'z']]
pca = PCA()
pca.fit(coords)
# Out:
# PCA()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.52990661, 0.35848899, 0.1116044 ])

# %%
pca.feature_names_in_
# Out:
# array(['x', 'y', 'z'], dtype=object)

# %%
sns.barplot(y=pca.explained_variance_ratio_, x=pca.feature_names_in_)
plt.title('PCA explained variance')
# Out:
# Text(0.5, 1.0, 'PCA explained variance')

# %%
all_results.groupby('e')['score'].describe()
# Out:
#     count       mean       std   min   25%   50%   75%  max
# e
# 16  960.0 -11.403125  1.132380 -13.9 -12.1 -11.7 -11.0 -5.9
# 32  960.0 -11.592083  1.071811 -13.8 -12.2 -11.8 -11.3 -7.6
# 64  960.0 -11.730625  0.998821 -13.9 -12.3 -11.9 -11.3 -7.8

# %% [markdown]
# # Alt: DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
model_3 = DBSCAN(eps=2.5, min_samples=6)

# %%
all_results['DBSCAN'] = model_3.fit_predict(to_cluster)

# %%
plot_clusters(all_results, cluster='DBSCAN', alpha=0.3)

# %%
def get_cluster_centroid(df, labels='DBSCAN'):
    out = []
    for i in df[labels].unique():
        subset = df[df[labels] == i]
        out.append([subset.centroid_x.mean(), subset.centroid_y.mean(), subset.centroid_z.mean()])
    return out, df[labels].unique()

# %%
no_noise = all_results[all_results.DBSCAN != -1]
sns.scatterplot(x=no_noise.centroid_x, y=no_noise.centroid_y, hue=no_noise.DBSCAN, palette=sns.color_palette(n_colors=20), alpha=0.3)
plt.title('Clustered centroids - mean')
energies = no_noise.groupby('DBSCAN')['score'].mean().values
energies_median = no_noise.groupby('DBSCAN')['score'].median().values
cluster_centers, indicies = get_cluster_centroid(no_noise)
for centroid, energy, median, idx in zip(cluster_centers, energies, energies_median, indicies):
    if idx == -1:
        print('Skipped noisy samples')
        continue
    energy_str = str(energy)[:6]
    energy_median = str(median)[:6]
    x = centroid[0]
    y = centroid[1]
    #plt.text(x + 0.5, y, energy_str, horizontalalignment='left', size='medium', color='black', weight='semibold')
    plt.text(x + 3, y - 2, energy_str, horizontalalignment='left', size='medium', color='black', weight='bold')
# Out:
# /tmp/ipykernel_37759/603140955.py:2: UserWarning: The palette list has more values (20) than needed (1), which may not be intended.
#   sns.scatterplot(x=no_noise.centroid_x, y=no_noise.centroid_y, hue=no_noise.DBSCAN, palette=sns.color_palette(n_colors=20), alpha=0.3)

# %%
no_noise = all_results[all_results.DBSCAN != -1]
sns.scatterplot(x=no_noise.centroid_x, y=no_noise.centroid_y, hue=no_noise.DBSCAN, palette=sns.color_palette(n_colors=20), alpha=0.3)
plt.title('Clustered centroids - median')
energies = no_noise.groupby('DBSCAN')['score'].mean().values
energies_median = no_noise.groupby('DBSCAN')['score'].median().values
cluster_centers, indicies = get_cluster_centroid(no_noise)
for centroid, energy, median, idx in zip(cluster_centers, energies, energies_median, indicies):
    if idx == -1:
        noise = len(all_results[all_results.DBSCAN == -1])
        print(f'Skipped {noise} noisy samples')
        continue
    energy_str = str(energy)[:6]
    energy_median = str(median)[:6]
    x = centroid[0]
    y = centroid[1]
    #plt.text(x + 0.5, y, energy_str, horizontalalignment='left', size='medium', color='black', weight='semibold')
    plt.text(x + 3, y - 2, energy_median, horizontalalignment='left', size='medium', color='black', weight='bold')
# Out:
# /tmp/ipykernel_37759/119756924.py:2: UserWarning: The palette list has more values (20) than needed (1), which may not be intended.
#   sns.scatterplot(x=no_noise.centroid_x, y=no_noise.centroid_y, hue=no_noise.DBSCAN, palette=sns.color_palette(n_colors=20), alpha=0.3)

# %%
cluster_centers, indicies = get_cluster_centroid(no_noise)
cluster_centers
# Out:
# [[39.00823791987502, 28.141771246012176, 28.672789579723396]]

# %%
from sklearn.neighbors import NearestNeighbors

# %%
neighbors = NearestNeighbors(n_neighbors=6)
neighbors_fit = neighbors.fit(to_cluster)
distances, indices = neighbors_fit.kneighbors(to_cluster)

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)
plt.xlim(2825, 2979)
plt.ylabel('Epsilon')
plt.xlabel('N')
plt.title('K-distance plot')
# Out:
# Text(0.5, 1.0, 'K-distance plot')

# %%
model_3a = DBSCAN(eps=1, min_samples=6)
all_results['DBSCAN_1'] = model_3a.fit_predict(to_cluster)

# %%
plot_clusters(all_results, cluster='DBSCAN_1', alpha=0.1)

# %%
no_noise = all_results[all_results.DBSCAN_1 != -1]
sns.scatterplot(x=no_noise.centroid_x, y=no_noise.centroid_y, hue=no_noise.DBSCAN_6, palette=sns.color_palette(n_colors=10), alpha=0.3)
plt.title('Clustered centroids - median')
energies = no_noise.groupby('DBSCAN_1')['score'].mean().values
energies_median = no_noise.groupby('DBSCAN_1')['score'].median().values
cluster_centers, indicies = get_cluster_centroid(no_noise, labels='DBSCAN_1')
for centroid, energy, median, idx in zip(cluster_centers, energies, energies_median, indicies):
    if idx == -1:
        noise = len(all_results[all_results.DBSCAN_1 == -1])
        print(f'Skipped {noise} noisy samples')
        continue
    energy_str = str(energy)[:6]
    energy_median = str(median)[:6]
    x = centroid[0]
    y = centroid[1]
    #plt.text(x + 0.5, y, energy_str, horizontalalignment='left', size='medium', color='black', weight='semibold')
    plt.text(x, y, energy_median, horizontalalignment='left', size='medium', color='black', weight='bold')
# Out:
# /tmp/ipykernel_37759/2475536818.py:2: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.scatterplot(x=no_noise.centroid_x, y=no_noise.centroid_y, hue=no_noise.DBSCAN_6, palette=sns.color_palette(n_colors=10), alpha=0.3)

# %%
no_noise = all_results[all_results.DBSCAN_6 != -1]
sns.scatterplot(x=no_noise.centroid_x, y=no_noise.centroid_y, hue=no_noise.DBSCAN_6, palette=sns.color_palette(n_colors=10), alpha=0.3)
plt.title('Clustered centroids - mean')
energies = no_noise.groupby('DBSCAN_6')['score'].mean().values
energies_median = no_noise.groupby('DBSCAN_6')['score'].median().values
cluster_centers, indicies = get_cluster_centroid(no_noise, labels='DBSCAN_6')
for centroid, energy, median, idx in zip(cluster_centers, energies, energies_median, indicies):
    energy_str = str(energy)[:6]
    energy_median = str(median)[:6]
    x = centroid[0]
    y = centroid[1]
    #plt.text(x + 0.5, y, energy_str, horizontalalignment='left', size='medium', color='black', weight='semibold')
    plt.text(x, y, energy_str, horizontalalignment='left', size='medium', color='black', weight='bold')
# Out:
# /tmp/ipykernel_37759/2528207509.py:2: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.scatterplot(x=no_noise.centroid_x, y=no_noise.centroid_y, hue=no_noise.DBSCAN_6, palette=sns.color_palette(n_colors=10), alpha=0.3)

# %%
no_noise.groupby('DBSCAN_6')['score'].describe()
# Out:
#            count       mean       std   min     25%   50%     75%   max
# DBSCAN_6
# 0         2788.0 -11.615818  1.030144 -13.9 -12.200 -11.8 -11.300  -5.9
# 1           12.0 -10.033333  0.835935 -11.4 -10.550  -9.9  -9.375  -8.8
# 2            8.0  -9.800000  2.348252 -12.4 -12.175  -9.4  -8.300  -6.1
# 3            8.0 -10.575000  1.497379 -12.2 -11.575 -10.9 -10.075  -7.6
# 4            7.0 -11.500000  0.326599 -11.9 -11.800 -11.4 -11.250 -11.1

# %%
no_noise.head()
# Out:
#    index      name  pose  score  \
# 0      0  1_1_2381   0.0  -13.0
# 1      1  1_1_2381   1.0  -12.4
# 3      3  1_1_2381   3.0  -12.1
# 4      4  1_1_2381   4.0  -12.0
# 5      5  1_1_2381   5.0  -11.9
#
#                                             centroid  \
# 0  Point(37.860491017964065, 26.84025748502995, 2...
# 1  Point(38.34494011976049, 26.846532934131737, 2...
# 3  Point(39.52835928143713, 30.022311377245487, 2...
# 4  Point(37.725628742514985, 27.81560479041917, 2...
# 5  Point(42.108886227544915, 29.835622754491023, ...
#
#                                               coords   e  centroid_x  \
# 0  [[33.494, 26.759, 24.796], [34.113, 25.84, 24....  16   37.860491
# 1  [[33.996, 28.656, 24.791], [34.613, 28.669, 23...  16   38.344940
# 3  [[37.14, 32.721, 30.591], [37.544, 33.883, 30....  16   39.528359
# 4  [[33.683, 28.98, 25.101], [34.685, 28.679, 24....  16   37.725629
# 5  [[38.998, 29.53, 29.19], [39.323, 28.407, 28.7...  16   42.108886
#
#    centroid_y  centroid_z  labels  pocket  DBSCAN  DBSCAN_6
# 0   26.840257   28.370784       1       2       0         0
# 1   26.846533   28.857970       1       2       0         0
# 3   30.022311   28.704599       2       0       0         0
# 4   27.815605   29.074371       2       0       0         0
# 5   29.835623   30.737287       0       1       0         0

# %% [markdown]
# # Pocket - 7

# %%
pocket_7 = no_noise[no_noise.DBSCAN_6 == 7]
len(pocket_7)
# Out:
# 0

# %%
pocket_7.sort_values(by='score').head()
# Out:
# Empty DataFrame
# Columns: [index, name, pose, score, centroid, coords, e, centroid_x, centroid_y, centroid_z, labels, pocket, DBSCAN, DBSCAN_6]
# Index: []

# %%
coords = pocket_7.coords.tolist()

# %%
type(coords[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 type(coords[0])
#
# IndexError: list index out of range

# %%
coords[0].shape

# %%
coords[1].shape

# %%
added = np.concatenate(coords, axis=0)
added.shape

# %%
from utils.centroid import get_box

# %%
center, dims = get_box(added, extend=0)
print('gridbox ', *center, *dims, sep=', ')

# %% [markdown]
# # Pocket - 2

# %%
pocket_2 = no_noise[no_noise.DBSCAN_6 == 2]
len(pocket_2)

# %%
coords = pocket_2.coords.tolist()
added = np.concatenate(coords, axis=0)
added.shape

# %%
center, dims = get_box(added, extend=0)
print('gridbox ', *center, *dims, sep=', ')
